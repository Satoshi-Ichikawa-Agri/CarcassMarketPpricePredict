# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from settings import DbSetting
from models.models import CarcassMarketPrice, create_table

# %%
# DB接続
db_setting = DbSetting()
engine = db_setting.get_db_engine()
session = db_setting.get_db_session()

# %%
sql = 'select * from carcass_market_price'
df = pd.read_sql(
    sql = sql,
    con = engine,
    )
# Out:
# 2023-05-24 10:25:15,824 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2023-05-24 10:25:15,825 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-05-24 10:25:15,827 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2023-05-24 10:25:15,827 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-05-24 10:25:15,828 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2023-05-24 10:25:15,829 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-05-24 10:25:15,830 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-05-24 10:25:15,831 INFO sqlalchemy.engine.Engine DESCRIBE `dev_carcass_db`.`select * from carcass_market_price`
# 2023-05-24 10:25:15,831 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-05-24 10:25:15,834 INFO sqlalchemy.engine.Engine select * from carcass_market_price
# 2023-05-24 10:25:15,835 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-05-24 10:25:15,851 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
df
# Out:
#       id market_date  nationwide_slaughter  zennoh_high_price
# 0      1  2022-04-01                 61900                486  \
# 1      2  2022-04-04                 61600                494
# 2      3  2022-04-05                 64400                488
# 3      4  2022-04-06                 65200                476
# 4      5  2022-04-07                 64500                471
# ..   ...         ...                   ...                ...
# 253  254  2023-04-24                 65600                602
# 254  255  2023-04-25                 68900                604
# 255  256  2023-04-26                 69200                598
# 256  257  2023-04-27                 69300                590
# 257  258  2023-04-28                 69200                597
#
#      zennoh_middle_price  tokyo_high_price  tokyo_middle_price
# 0                    455             500.0               466.0  \
# 1                    461             490.0               460.0
# ...

# %%
dataset = pd.read_sql(sql=sql, con=engine)
X = dataset.iloc[:, 2:-2].values # 独立変数
y = dataset.iloc[:, 2:-2].values # 従属変数
# Out:
# 2023-05-24 11:14:11,581 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-05-24 11:14:11,581 INFO sqlalchemy.engine.Engine DESCRIBE `dev_carcass_db`.`select * from carcass_market_price`
# 2023-05-24 11:14:11,582 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-05-24 11:14:11,584 INFO sqlalchemy.engine.Engine select * from carcass_market_price
# 2023-05-24 11:14:11,584 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-05-24 11:14:11,593 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
X
# Out:
# array([[61900.,   486.,   455., ...,   338.,   316.,   152.],
#        [61600.,   494.,   461., ...,   462.,   326.,   155.],
#        [64400.,   488.,   460., ...,   450.,   327.,   142.],
#        ...,
#        [69200.,   598.,   586., ...,   526.,   356.,   100.],
#        [69300.,   590.,   574., ...,   529.,   413.,   144.],
#        [69200.,   597.,   583., ...,   521.,   435.,   146.]])

# %%
y
# Out:
# array([[61900.,   486.,   455., ...,   338.,   316.,   152.],
#        [61600.,   494.,   461., ...,   462.,   326.,   155.],
#        [64400.,   488.,   460., ...,   450.,   327.,   142.],
#        ...,
#        [69200.,   598.,   586., ...,   526.,   356.,   100.],
#        [69300.,   590.,   574., ...,   529.,   413.,   144.],
#        [69200.,   597.,   583., ...,   521.,   435.,   146.]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
